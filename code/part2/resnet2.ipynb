# %%
EPOCH_NUMBER = 100
LEARNING_RATE = 0.001
TENSOR_SIZE = 128
BATCH_SIZE = 32
dropout_rate = 0.3
num_classes = 8

# %%
import os
import matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline

dataset_path = './../Micro_Organism'

from torchvision.datasets import ImageFolder
from torchvision.transforms import ToTensor, Resize, Compose, Normalize, RandomHorizontalFlip, RandomRotation, RandomVerticalFlip, ColorJitter

transform = Compose([
    Resize((TENSOR_SIZE, TENSOR_SIZE)),
    ToTensor(),
    RandomRotation(degrees=30), # new here
    RandomHorizontalFlip(), # new here
    RandomVerticalFlip(), # new here
    ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1, hue=0.1), # new here
    Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

dataset = ImageFolder(dataset_path, transform=transform)

import torch
from torch.utils.data import random_split

torch.manual_seed(42)
train_size = 400
val_size = 160
test_size = len(dataset) - (train_size + val_size)

train_dataset, validation_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size])

def count_labels(dataset_subset, dataset_targets, num_classes):
    indices = dataset_subset.indices
    labels = [dataset_targets[i] for i in indices]
    counts = [labels.count(i) for i in range(num_classes)]
    return counts

num_classes = 8

labels = dataset.targets

train_counts = count_labels(train_dataset, labels, num_classes)
val_counts = count_labels(validation_dataset, labels, num_classes)
test_counts = count_labels(test_dataset, labels, num_classes)

print("Training set class distribution:", train_counts)
print("Validation set class distribution:", val_counts)
print("Test set class distribution:", test_counts)
# Out:
# Training set class distribution: [33, 82, 33, 78, 47, 46, 42, 39]
# Validation set class distribution: [15, 32, 10, 35, 17, 17, 18, 16]
# Test set class distribution: [24, 54, 33, 39, 21, 23, 15, 20]

# %%
from torch.utils.data.dataloader import DataLoader

batch_size = BATCH_SIZE
train_dataloader = DataLoader(train_dataset, batch_size, shuffle = True, num_workers = 4, pin_memory = True)
validation_dataloader = DataLoader(validation_dataset, batch_size * 2, num_workers = 4, pin_memory = True)
test_dataloader = DataLoader(test_dataset, batch_size * 2, num_workers = 4, pin_memory = True)

# %%
import torch.nn as nn
import torch.nn.functional as F

class ImageClassificationModel(nn.Module):
  def training_step(self, batch):
    images, labels = batch
    # Generate predictions
    out = self(images)
    # Calculate loss
    loss = F.cross_entropy(out, labels)
    return loss

  def validation_step(self, batch):
    images, labels = batch
    out = self(images)
    loss = F.cross_entropy(out, labels)
    # Calculate accuracy
    acc = accuracy(out, labels)
    return {'validation_loss': loss.detach(), 'validation_accuracy': acc} 

  def validation_epoch_end(self, outputs):
      batch_losses = [x['validation_loss'] for x in outputs]
      # Combine losses
      epoch_loss = torch.stack(batch_losses).mean()
      batch_accs = [x['validation_accuracy'] for x in outputs]
      # Combine accuracies
      epoch_acc = torch.stack(batch_accs).mean()
      return {'validation_loss': epoch_loss.item(), 'validation_accuracy': epoch_acc.item()}

  def epoch_end(self, epoch, result):
      train_loss, val_loss, val_acc = result['train_loss'], result['validation_loss'], result['validation_accuracy']
      print(f"Epoch [{epoch}/{EPOCH_NUMBER}], Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_acc:.4f}")


def accuracy(outputs, labels):
  _, preds = torch.max(outputs, dim=1)
  return torch.tensor(torch.sum(preds == labels).item() / len(preds))

# %%
from torchvision import models
from torchvision.models import ResNet18_Weights

class CustomResNet(ImageClassificationModel):
    def __init__(self, num_classes=8):
        super().__init__()
        self.resnet = models.resnet18(weights=ResNet18_Weights.DEFAULT)

        # Freeze all layers
        for param in self.resnet.parameters():
            param.requires_grad = False

        # Unfreeze the last two convolutional layers in layer4
        for param in self.resnet.layer4[1].parameters():
            param.requires_grad = True

        # Replace and unfreeze the FC layer
        self.resnet.fc = nn.Linear(in_features=512, out_features=num_classes)
        for param in self.resnet.fc.parameters():
            param.requires_grad = True

    def forward(self, x):
        return self.resnet(x)

model = CustomResNet(num_classes)
model
# Out:
# CustomResNet(
#   (resnet): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Linear(in_features=512, out_features=8, bias=True)
#   )
# )

# %%
def print_layer_requires_grad(model):
    for name, param in model.named_parameters():
        print(name, param.requires_grad)

# Call the function to see the status of the layers in resnet18
print_layer_requires_grad(model)
# Out:
# resnet.conv1.weight False
# resnet.bn1.weight False
# resnet.bn1.bias False
# resnet.layer1.0.conv1.weight False
# resnet.layer1.0.bn1.weight False
# resnet.layer1.0.bn1.bias False
# resnet.layer1.0.conv2.weight False
# resnet.layer1.0.bn2.weight False
# resnet.layer1.0.bn2.bias False
# resnet.layer1.1.conv1.weight False
# resnet.layer1.1.bn1.weight False
# resnet.layer1.1.bn1.bias False
# resnet.layer1.1.conv2.weight False
# resnet.layer1.1.bn2.weight False
# resnet.layer1.1.bn2.bias False
# resnet.layer2.0.conv1.weight False
# resnet.layer2.0.bn1.weight False
# resnet.layer2.0.bn1.bias False
# resnet.layer2.0.conv2.weight False
# resnet.layer2.0.bn2.weight False
# resnet.layer2.0.bn2.bias False
# resnet.layer2.0.downsample.0.weight False
# resnet.layer2.0.downsample.1.weight False
# resnet.layer2.0.downsample.1.bias False
# resnet.layer2.1.conv1.weight False
# resnet.layer2.1.bn1.weight False
# resnet.layer2.1.bn1.bias False
# resnet.layer2.1.conv2.weight False
# resnet.layer2.1.bn2.weight False
# resnet.layer2.1.bn2.bias False
# resnet.layer3.0.conv1.weight False
# resnet.layer3.0.bn1.weight False
# resnet.layer3.0.bn1.bias False
# resnet.layer3.0.conv2.weight False
# resnet.layer3.0.bn2.weight False
# resnet.layer3.0.bn2.bias False
# resnet.layer3.0.downsample.0.weight False
# resnet.layer3.0.downsample.1.weight False
# resnet.layer3.0.downsample.1.bias False
# resnet.layer3.1.conv1.weight False
# resnet.layer3.1.bn1.weight False
# resnet.layer3.1.bn1.bias False
# resnet.layer3.1.conv2.weight False
# resnet.layer3.1.bn2.weight False
# resnet.layer3.1.bn2.bias False
# resnet.layer4.0.conv1.weight False
# resnet.layer4.0.bn1.weight False
# resnet.layer4.0.bn1.bias False
# resnet.layer4.0.conv2.weight False
# resnet.layer4.0.bn2.weight False
# resnet.layer4.0.bn2.bias False
# resnet.layer4.0.downsample.0.weight False
# resnet.layer4.0.downsample.1.weight False
# resnet.layer4.0.downsample.1.bias False
# resnet.layer4.1.conv1.weight True
# resnet.layer4.1.bn1.weight True
# resnet.layer4.1.bn1.bias True
# resnet.layer4.1.conv2.weight True
# resnet.layer4.1.bn2.weight True
# resnet.layer4.1.bn2.bias True
# resnet.fc.weight True
# resnet.fc.bias True

# %% [markdown]
# ```resnet.layer4.1.conv1.weight True
# resnet.layer4.1.bn1.weight True
# resnet.layer4.1.bn1.bias True
# resnet.layer4.1.conv2.weight True
# resnet.layer4.1.bn2.weight True
# resnet.layer4.1.bn2.bias True
# resnet.fc.weight True
# resnet.fc.bias True

# %%
def get_default_device():
    if torch.cuda.is_available():
        print('Using CUDA')
        return torch.device('cuda')
    else:
        print('Using CPU')
        return torch.device('cpu')
    
def to_device(data, device):
    if isinstance(data, (list, tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking = True)

class DeviceDataloader():
    def __init__(self, dataloader, device):
        self.dataloader = dataloader
        self.device = device

    def __iter__(self):
        for batch in self.dataloader:
            yield to_device(batch, self.device)

    def __len__(self):
        return len(self.dataloader)
    
device = get_default_device()
device
# Out:
# Using CUDA
# device(type='cuda')

# %%
train_dataloader = DeviceDataloader(train_dataloader,  device)
validation_dataloader = DeviceDataloader(validation_dataloader, device)
test_dataloader = DeviceDataloader(test_dataloader, device)

# %%
@torch.no_grad()
def evaluate(model, validation_loader):
    model.eval()
    outputs = [model.validation_step(batch) for batch in validation_loader]
    return model.validation_epoch_end(outputs)

def fit(epochs, lr, model, train_loader, validation_loader, opt_func=torch.optim.SGD):
    torch.cuda.empty_cache()
    history = []
    optimizer = opt_func(model.parameters(), lr)
    for epoch in range(epochs):
        # Training Phase 
        model.train()
        train_losses = []
        for batch in train_loader:
            loss = model.training_step(batch)
            train_losses.append(loss)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
        # Validation phase
        result = evaluate(model, validation_loader)
        result['train_loss'] = torch.stack(train_losses).mean().item()
        model.epoch_end(epoch, result)
        history.append(result)
    return history

model = to_device(model, device)
evaluate(model, validation_dataloader)
# Out:
# {'validation_loss': 2.3170595169067383, 'validation_accuracy': 0.15625}

# %%
num_epochs = EPOCH_NUMBER
opt_func = torch.optim.Adam
lr = LEARNING_RATE

# %%
history = fit(num_epochs, lr, model, train_dataloader, validation_dataloader, opt_func=opt_func)
# Out:
# Epoch [0/100], Training Loss: 1.9156, Validation Loss: 2.5019, Validation Accuracy: 0.4948
# Epoch [1/100], Training Loss: 1.0384, Validation Loss: 1.5497, Validation Accuracy: 0.4844
# Epoch [2/100], Training Loss: 0.8163, Validation Loss: 1.4147, Validation Accuracy: 0.5781
# Epoch [3/100], Training Loss: 0.6082, Validation Loss: 1.4915, Validation Accuracy: 0.5885
# Epoch [4/100], Training Loss: 0.4960, Validation Loss: 1.5024, Validation Accuracy: 0.5573
# Epoch [5/100], Training Loss: 0.5551, Validation Loss: 1.7488, Validation Accuracy: 0.5677
# Epoch [6/100], Training Loss: 0.4124, Validation Loss: 1.5257, Validation Accuracy: 0.5573
# Epoch [7/100], Training Loss: 0.3547, Validation Loss: 1.4026, Validation Accuracy: 0.6094
# Epoch [8/100], Training Loss: 0.2600, Validation Loss: 1.6148, Validation Accuracy: 0.5729
# Epoch [9/100], Training Loss: 0.2668, Validation Loss: 1.5909, Validation Accuracy: 0.5990
# Epoch [10/100], Training Loss: 0.2779, Validation Loss: 1.8846, Validation Accuracy: 0.5208
# Epoch [11/100], Training Loss: 0.1934, Validation Loss: 1.7545, Validation Accuracy: 0.5938
# Epoch [12/100], Training Loss: 0.2347, Validation Loss: 1.5709, Validation Accuracy: 0.6615
# Epoch [13/100], Training Loss: 0.2774, Validation Loss: 1.9084, Validation Accuracy: 0.5365
# Epoch [14/100], Training Loss: 0.1803, Validation Loss: 1.8200, Validation Accuracy: 0.4948
# Epoch [15/100], Training Loss: 0.1973, Validation Loss: 1.7686, Validation Accuracy: 0.5625
# Epoch [16/100], Training Loss: 0.2525, Validation Loss: 1.7612, Validation Accuracy: 0.5938
# Epoch [17/100], Training Loss: 0.2359, Validation Loss: 2.1195, Validation Accuracy: 0.5000
# Epoch [18/100], Training Loss: 0.1808, Validation Loss: 1.7193, Validation Accuracy: 0.5833
# Epoch [19/100], Training Loss: 0.2363, Validation Loss: 1.8385, Validation Accuracy: 0.5573
# Epoch [20/100], Training Loss: 0.2154, Validation Loss: 2.2563, Validation Accuracy: 0.5312
# Epoch [21/100], Training Loss: 0.1769, Validation Loss: 1.8912, Validation Accuracy: 0.5573
# Epoch [22/100], Training Loss: 0.2380, Validation Loss: 1.8675, Validation Accuracy: 0.5417
# Epoch [23/100], Training Loss: 0.2284, Validation Loss: 2.0286, Validation Accuracy: 0.5260
# Epoch [24/100], Training Loss: 0.1513, Validation Loss: 2.1093, Validation Accuracy: 0.5365
# Epoch [25/100], Training Loss: 0.2336, Validation Loss: 1.8973, Validation Accuracy: 0.4635
# Epoch [26/100], Training Loss: 0.1683, Validation Loss: 1.8349, Validation Accuracy: 0.5833
# Epoch [27/100], Training Loss: 0.2080, Validation Loss: 1.8978, Validation Accuracy: 0.5260
# Epoch [28/100], Training Loss: 0.1970, Validation Loss: 1.9837, Validation Accuracy: 0.5677
# Epoch [29/100], Training Loss: 0.1732, Validation Loss: 2.1798, Validation Accuracy: 0.5781
# Epoch [30/100], Training Loss: 0.1356, Validation Loss: 2.4208, Validation Accuracy: 0.5365
# Epoch [31/100], Training Loss: 0.1759, Validation Loss: 2.3075, Validation Accuracy: 0.5469
# Epoch [32/100], Training Loss: 0.0788, Validation Loss: 2.0316, Validation Accuracy: 0.5312
# Epoch [33/100], Training Loss: 0.1457, Validation Loss: 1.9515, Validation Accuracy: 0.5208
# Epoch [34/100], Training Loss: 0.1352, Validation Loss: 2.0536, Validation Accuracy: 0.5469
# Epoch [35/100], Training Loss: 0.1844, Validation Loss: 2.0483, Validation Accuracy: 0.5833
# Epoch [36/100], Training Loss: 0.1358, Validation Loss: 2.1764, Validation Accuracy: 0.5417
# Epoch [37/100], Training Loss: 0.1162, Validation Loss: 1.7626, Validation Accuracy: 0.5833
# Epoch [38/100], Training Loss: 0.0928, Validation Loss: 2.0999, Validation Accuracy: 0.5000
# Epoch [39/100], Training Loss: 0.0960, Validation Loss: 1.9857, Validation Accuracy: 0.5677
# Epoch [40/100], Training Loss: 0.1037, Validation Loss: 2.0572, Validation Accuracy: 0.5781
# Epoch [41/100], Training Loss: 0.1260, Validation Loss: 2.2633, Validation Accuracy: 0.5677
# Epoch [42/100], Training Loss: 0.1212, Validation Loss: 2.1749, Validation Accuracy: 0.5521
# Epoch [43/100], Training Loss: 0.0941, Validation Loss: 1.8953, Validation Accuracy: 0.5521
# Epoch [44/100], Training Loss: 0.0812, Validation Loss: 2.1642, Validation Accuracy: 0.5365
# Epoch [45/100], Training Loss: 0.0825, Validation Loss: 2.3693, Validation Accuracy: 0.5312
# Epoch [46/100], Training Loss: 0.1050, Validation Loss: 2.4050, Validation Accuracy: 0.5521
# Epoch [47/100], Training Loss: 0.0940, Validation Loss: 2.1995, Validation Accuracy: 0.5417
# Epoch [48/100], Training Loss: 0.0708, Validation Loss: 2.0779, Validation Accuracy: 0.6146
# Epoch [49/100], Training Loss: 0.0926, Validation Loss: 2.1814, Validation Accuracy: 0.5417
# Epoch [50/100], Training Loss: 0.0964, Validation Loss: 2.1362, Validation Accuracy: 0.5625
# Epoch [51/100], Training Loss: 0.0778, Validation Loss: 2.0050, Validation Accuracy: 0.6042
# Epoch [52/100], Training Loss: 0.0987, Validation Loss: 2.2374, Validation Accuracy: 0.5625
# Epoch [53/100], Training Loss: 0.1398, Validation Loss: 2.1456, Validation Accuracy: 0.5781
# Epoch [54/100], Training Loss: 0.0945, Validation Loss: 2.3002, Validation Accuracy: 0.5990
# Epoch [55/100], Training Loss: 0.1165, Validation Loss: 2.6828, Validation Accuracy: 0.5469
# Epoch [56/100], Training Loss: 0.1094, Validation Loss: 2.3906, Validation Accuracy: 0.5469
# Epoch [57/100], Training Loss: 0.1176, Validation Loss: 2.6908, Validation Accuracy: 0.5469
# Epoch [58/100], Training Loss: 0.1111, Validation Loss: 2.0958, Validation Accuracy: 0.5990
# Epoch [59/100], Training Loss: 0.0809, Validation Loss: 2.4387, Validation Accuracy: 0.5469
# Epoch [60/100], Training Loss: 0.0864, Validation Loss: 2.0927, Validation Accuracy: 0.5833
# Epoch [61/100], Training Loss: 0.0484, Validation Loss: 2.4970, Validation Accuracy: 0.5312
# Epoch [62/100], Training Loss: 0.0773, Validation Loss: 2.4194, Validation Accuracy: 0.5417
# Epoch [63/100], Training Loss: 0.1133, Validation Loss: 2.2559, Validation Accuracy: 0.5469
# Epoch [64/100], Training Loss: 0.0721, Validation Loss: 2.0035, Validation Accuracy: 0.5677
# Epoch [65/100], Training Loss: 0.0966, Validation Loss: 2.0966, Validation Accuracy: 0.6094
# Epoch [66/100], Training Loss: 0.0568, Validation Loss: 1.9148, Validation Accuracy: 0.5990
# Epoch [67/100], Training Loss: 0.1117, Validation Loss: 2.2254, Validation Accuracy: 0.5729
# Epoch [68/100], Training Loss: 0.0767, Validation Loss: 2.6032, Validation Accuracy: 0.5260
# Epoch [69/100], Training Loss: 0.0740, Validation Loss: 2.4846, Validation Accuracy: 0.5417
# Epoch [70/100], Training Loss: 0.0440, Validation Loss: 2.2867, Validation Accuracy: 0.5885
# Epoch [71/100], Training Loss: 0.0795, Validation Loss: 2.5953, Validation Accuracy: 0.5312
# Epoch [72/100], Training Loss: 0.0757, Validation Loss: 2.3783, Validation Accuracy: 0.5781
# Epoch [73/100], Training Loss: 0.0957, Validation Loss: 2.5822, Validation Accuracy: 0.5365
# Epoch [74/100], Training Loss: 0.1191, Validation Loss: 2.0016, Validation Accuracy: 0.5729
# Epoch [75/100], Training Loss: 0.1399, Validation Loss: 2.5768, Validation Accuracy: 0.5417
# Epoch [76/100], Training Loss: 0.1105, Validation Loss: 2.2749, Validation Accuracy: 0.5573
# Epoch [77/100], Training Loss: 0.0775, Validation Loss: 2.0944, Validation Accuracy: 0.6146
# Epoch [78/100], Training Loss: 0.1145, Validation Loss: 2.4811, Validation Accuracy: 0.5052
# Epoch [79/100], Training Loss: 0.0984, Validation Loss: 2.1807, Validation Accuracy: 0.5677
# Epoch [80/100], Training Loss: 0.0509, Validation Loss: 2.4809, Validation Accuracy: 0.5417
# Epoch [81/100], Training Loss: 0.0840, Validation Loss: 2.4560, Validation Accuracy: 0.5156
# Epoch [82/100], Training Loss: 0.0664, Validation Loss: 2.3529, Validation Accuracy: 0.5260
# Epoch [83/100], Training Loss: 0.0778, Validation Loss: 2.4080, Validation Accuracy: 0.5521
# Epoch [84/100], Training Loss: 0.0642, Validation Loss: 2.6178, Validation Accuracy: 0.5365
# Epoch [85/100], Training Loss: 0.0560, Validation Loss: 2.5491, Validation Accuracy: 0.5417
# Epoch [86/100], Training Loss: 0.0567, Validation Loss: 2.5897, Validation Accuracy: 0.5156
# Epoch [87/100], Training Loss: 0.0628, Validation Loss: 2.6180, Validation Accuracy: 0.5625
# Epoch [88/100], Training Loss: 0.0697, Validation Loss: 2.3808, Validation Accuracy: 0.5312
# Epoch [89/100], Training Loss: 0.0378, Validation Loss: 2.4541, Validation Accuracy: 0.5677
# Epoch [90/100], Training Loss: 0.0592, Validation Loss: 2.5056, Validation Accuracy: 0.5365
# Epoch [91/100], Training Loss: 0.0717, Validation Loss: 2.7428, Validation Accuracy: 0.5365
# Epoch [92/100], Training Loss: 0.0478, Validation Loss: 2.2791, Validation Accuracy: 0.5677
# Epoch [93/100], Training Loss: 0.0835, Validation Loss: 2.8049, Validation Accuracy: 0.5573
# Epoch [94/100], Training Loss: 0.0675, Validation Loss: 2.8143, Validation Accuracy: 0.5729
# Epoch [95/100], Training Loss: 0.0877, Validation Loss: 2.8825, Validation Accuracy: 0.5104
# Epoch [96/100], Training Loss: 0.1994, Validation Loss: 3.0575, Validation Accuracy: 0.5417
# Epoch [97/100], Training Loss: 0.0887, Validation Loss: 2.6341, Validation Accuracy: 0.5417
# Epoch [98/100], Training Loss: 0.0976, Validation Loss: 2.9043, Validation Accuracy: 0.4948
# Epoch [99/100], Training Loss: 0.0784, Validation Loss: 2.4643, Validation Accuracy: 0.5677

# %%
def plot_accuracies(history):
    accuracies = [x['validation_accuracy'] for x in history]
    plt.plot(accuracies, '-x')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Accuracy vs Number of epochs')

plot_accuracies(history)

# %%
def plot_losses(history):
    train_losses = [x.get('train_loss') for x in history]
    val_losses = [x['validation_loss'] for x in history]
    plt.plot(train_losses, '-bx')
    plt.plot(val_losses, '-rx')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(['Training', 'Validation'])
    plt.title('Loss vs Number of epochs')

plot_losses(history)

# %% [markdown]
# The model also seems to be overfitting as the training loss is getting lower but the validation loss is getting higher, however the results are much better here.
#
# The accuracy is consistently over 40% and some points it's over 50%. However if we take the point `Epoch [3/100], Training Loss: 0.6082, Validation Loss: 1.4915, Validation Accuracy: 0.5885` as the point where validation loss goes higher while training loss drops by looking at Loss vs Number of Epochs plot, then our accuracy can be considered as `59%`

# %%
evaluate(model, test_dataloader)
# Out:
# {'validation_loss': 3.008002758026123,
#  'validation_accuracy': 0.5470861196517944}

# %% [markdown]
# **Test Accuracy**: 55%

# %%
torch.save(model.state_dict(), 'resnet2.pth')

# %%
from sklearn.metrics import confusion_matrix

def get_all_preds(model, loader, device):
    all_preds = torch.tensor([], dtype=torch.long).to(device)
    for batch in loader:
        images, labels = batch
        images = to_device(images, device)
        preds = model(images)
        all_preds = torch.cat((all_preds, preds.argmax(dim=1)), dim=0)
    return all_preds

with torch.no_grad():
    all_preds = get_all_preds(model, test_dataloader, device)
    all_labels = torch.tensor([test_dataloader.dataloader.dataset.dataset.targets[i] for i in test_dataloader.dataloader.dataset.indices], dtype=torch.long)

cm = confusion_matrix(all_labels.numpy(), all_preds.cpu().numpy())

# %%
import matplotlib.pyplot as plt
import itertools
import numpy as np

def normalize_cm(cm: np.ndarray) -> np.ndarray:
    print("Confusion Matrix (Normalized)")
    return cm.astype("float") / cm.sum(axis=1)[:, np.newaxis]

def plot_matrix(cm, classes, cmap, title, font_size):
    tick_marks = np.arange(len(classes))
    plt.imshow(cm, interpolation="nearest", cmap=cmap)
    plt.title(title, fontsize=font_size + 4)
    plt.colorbar()
    plt.xticks(tick_marks, classes, rotation=60)
    plt.yticks(tick_marks, classes)


def confusion_matrix(cm, classes, normalize=False, title="Confusion Matrix Dropout2", cmap=plt.cm.RdPu):
    cm = normalize_cm(cm)

    font_size = 10
    plot_matrix(cm, classes, cmap, title, font_size)

    if normalize:
        fmt = ".2f"
    else:
        fmt = "d"

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(
            j,
            i, format(cm[i, j], fmt), 
            horizontalalignment="center", 
            color="white" if cm[i, j] > thresh else "black", 
            size="medium"
        )

    plt.tight_layout()
    plt.ylabel("Actual Label", fontsize=font_size + 2)
    plt.xlabel("Predicted Label", fontsize=font_size + 2)

microorganism_types = ["Amoeba", "Euglena", "Hydra", "Paramecium", "Rod_bacteria", "Spherical_bacteria", "Spiral_bacteria", "Yeast"]
confusion_matrix(cm, classes=microorganism_types , normalize=True)
plt.show()
# Out:
# Confusion Matrix (Normalized)
