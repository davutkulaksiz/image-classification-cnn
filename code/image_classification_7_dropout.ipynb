# %%
EPOCH_NUMBER = 100
LEARNING_RATE = 0.001
TENSOR_SIZE = 128
BATCH_SIZE = 32
dropout_rate = 0.1

# %%
import os
import matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline

dataset_path = './Micro_Organism'

from torchvision.datasets import ImageFolder
from torchvision.transforms import ToTensor, Resize, Compose, Normalize, RandomHorizontalFlip, RandomRotation, RandomVerticalFlip, ColorJitter

transform = Compose([
    Resize((TENSOR_SIZE, TENSOR_SIZE)),
    ToTensor(),
    RandomRotation(degrees=30), # new here
    RandomHorizontalFlip(), # new here
    RandomVerticalFlip(), # new here
    ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1, hue=0.1), # new here
    Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

dataset = ImageFolder(dataset_path, transform=transform)

import torch
from torch.utils.data import random_split

torch.manual_seed(42)
train_size = 400
val_size = 160
test_size = len(dataset) - (train_size + val_size)

train_dataset, validation_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size])

def count_labels(dataset_subset, dataset_targets, num_classes):
    indices = dataset_subset.indices
    labels = [dataset_targets[i] for i in indices]
    counts = [labels.count(i) for i in range(num_classes)]
    return counts

num_classes = 8

labels = dataset.targets

train_counts = count_labels(train_dataset, labels, num_classes)
val_counts = count_labels(validation_dataset, labels, num_classes)
test_counts = count_labels(test_dataset, labels, num_classes)

print("Training set class distribution:", train_counts)
print("Validation set class distribution:", val_counts)
print("Test set class distribution:", test_counts)
# Out:
# Training set class distribution: [33, 82, 33, 78, 47, 46, 42, 39]
# Validation set class distribution: [15, 32, 10, 35, 17, 17, 18, 16]
# Test set class distribution: [24, 54, 33, 39, 21, 23, 15, 20]

# %%
from torch.utils.data.dataloader import DataLoader

batch_size = BATCH_SIZE
train_dataloader = DataLoader(train_dataset, batch_size, shuffle = True, num_workers = 4, pin_memory = True)
validation_dataloader = DataLoader(validation_dataset, batch_size * 2, num_workers = 4, pin_memory = True)
test_dataloader = DataLoader(test_dataset, batch_size * 2, num_workers = 4, pin_memory = True)

# %%
import torch.nn as nn
import torch.nn.functional as F

class ImageClassificationModel(nn.Module):
  def training_step(self, batch):
    images, labels = batch
    # Generate predictions
    out = self(images)
    # Calculate loss
    loss = F.cross_entropy(out, labels)
    return loss

  def validation_step(self, batch):
    images, labels = batch
    out = self(images)
    loss = F.cross_entropy(out, labels)
    # Calculate accuracy
    acc = accuracy(out, labels)
    return {'validation_loss': loss.detach(), 'validation_accuracy': acc} 

  def validation_epoch_end(self, outputs):
      batch_losses = [x['validation_loss'] for x in outputs]
      # Combine losses
      epoch_loss = torch.stack(batch_losses).mean()
      batch_accs = [x['validation_accuracy'] for x in outputs]
      # Combine accuracies
      epoch_acc = torch.stack(batch_accs).mean()
      return {'validation_loss': epoch_loss.item(), 'validation_accuracy': epoch_acc.item()}

  def epoch_end(self, epoch, result):
      train_loss, val_loss, val_acc = result['train_loss'], result['validation_loss'], result['validation_accuracy']
      print(f"Epoch [{epoch}/{EPOCH_NUMBER}], Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_acc:.4f}")


def accuracy(outputs, labels):
  _, preds = torch.max(outputs, dim=1)
  return torch.tensor(torch.sum(preds == labels).item() / len(preds))

# %% [markdown]
# **Adding Residual Connection**
#
# 1. The **residual block** consists of the second convolutional layer **`(conv4)`** and its activation function **`(relu4)`**.

# %%
class CNNModelResidual(ImageClassificationModel):
    def __init__(self):
        super(CNNModelResidual, self).__init__()

        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, padding=1)
        self.relu1 = nn.ReLU()
        self.dropout1 = nn.Dropout(dropout_rate)
        self.pool = nn.MaxPool2d(2, 2)

        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)
        self.relu2 = nn.ReLU()
        self.dropout2 = nn.Dropout(dropout_rate)

        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.relu3 = nn.ReLU()
        self.dropout3 = nn.Dropout(dropout_rate)

        self.conv4 = nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1)
        self.relu4 = nn.ReLU()
        self.dropout4 = nn.Dropout(dropout_rate)

        self.conv5 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        self.relu5 = nn.ReLU()
        self.dropout5 = nn.Dropout(dropout_rate)

        self.conv6 = nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1)
        self.relu6 = nn.ReLU()
        self.dropout6 = nn.Dropout(dropout_rate)

        self.flatten = nn.Flatten()
        self.connected1 = nn.Linear(128 * int(TENSOR_SIZE / 2) * int(TENSOR_SIZE / 2), 8)
        
    def forward(self, value):
        # First Conv
        out = self.conv1(value)
        out = self.relu1(out)
        out = self.dropout1(out)
        out = self.pool(out)

        # Second Conv
        out = self.conv2(out)
        out = self.relu2(out)
        out = self.dropout2(out)

        # Third Conv
        out = self.conv3(out)
        out = self.relu3(out)
        out = self.dropout3(out)

        # Fourth Conv
        res4 = out
        out = self.conv4(out)
        out = self.relu4(out)
        out = self.dropout4(out)
        out = out + res4  # Residual connection

        # Fifth Conv
        out = self.conv5(out)
        out = self.relu5(out)
        out = self.dropout5(out)

        # Sixth Conv
        out = self.conv6(out)
        out = self.relu6(out)
        out = self.dropout6(out)

        ## Fully Connected Layers
        out = self.flatten(out)
        out = self.connected1(out)

        return out


model = CNNModelResidual()
model
# Out:
# CNNModelResidual(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu1): ReLU()
#   (dropout1): Dropout(p=0.1, inplace=False)
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu2): ReLU()
#   (dropout2): Dropout(p=0.1, inplace=False)
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu3): ReLU()
#   (dropout3): Dropout(p=0.1, inplace=False)
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu4): ReLU()
#   (dropout4): Dropout(p=0.1, inplace=False)
#   (conv5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu5): ReLU()
#   (dropout5): Dropout(p=0.1, inplace=False)
#   (conv6): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu6): ReLU()
#   (dropout6): Dropout(p=0.1, inplace=False)
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (connected1): Linear(in_features=524288, out_features=256, bias=True)
#   (relu7): ReLU()
#   (dropout7): Dropout(p=0.1, inplace=False)
#   (connected2): Linear(in_features=256, out_features=128, bias=True)
#   (relu8): ReLU()
#   (dropout8): Dropout(p=0.1, inplace=False)
#   (connected3): Linear(in_features=128, out_features=8, bias=True)
# )

# %%
def get_default_device():
    if torch.cuda.is_available():
        print('Using CUDA')
        return torch.device('cuda')
    else:
        print('Using CPU')
        return torch.device('cpu')
    
def to_device(data, device):
    if isinstance(data, (list, tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking = True)

class DeviceDataloader():
    def __init__(self, dataloader, device):
        self.dataloader = dataloader
        self.device = device

    def __iter__(self):
        for batch in self.dataloader:
            yield to_device(batch, self.device)

    def __len__(self):
        return len(self.dataloader)
    
device = get_default_device()
device
# Out:
# Using CUDA
# device(type='cuda')

# %%
train_dataloader = DeviceDataloader(train_dataloader,  device)
validation_dataloader = DeviceDataloader(validation_dataloader, device)
test_dataloader = DeviceDataloader(test_dataloader, device)

# %%
@torch.no_grad()
def evaluate(model, validation_loader):
    model.eval()
    outputs = [model.validation_step(batch) for batch in validation_loader]
    return model.validation_epoch_end(outputs)

def fit(epochs, lr, model, train_loader, validation_loader, opt_func=torch.optim.SGD):
    torch.cuda.empty_cache()
    history = []
    optimizer = opt_func(model.parameters(), lr)
    for epoch in range(epochs):
        # Training Phase 
        model.train()
        train_losses = []
        for batch in train_loader:
            loss = model.training_step(batch)
            train_losses.append(loss)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
        # Validation phase
        result = evaluate(model, validation_loader)
        result['train_loss'] = torch.stack(train_losses).mean().item()
        model.epoch_end(epoch, result)
        history.append(result)
    return history

model = to_device(model, device)
evaluate(model, validation_dataloader)
# Out:
# {'validation_loss': 2.0882840156555176,
#  'validation_accuracy': 0.0572916679084301}

# %%
num_epochs = EPOCH_NUMBER
opt_func = torch.optim.Adam
lr = LEARNING_RATE

# %%
history = fit(num_epochs, lr, model, train_dataloader, validation_dataloader, opt_func=opt_func)
# Out:
# Epoch [0/100], Training Loss: 2.1512, Validation Loss: 2.0688, Validation Accuracy: 0.2031
# Epoch [1/100], Training Loss: 2.0323, Validation Loss: 2.0328, Validation Accuracy: 0.2031
# Epoch [2/100], Training Loss: 1.9920, Validation Loss: 1.9540, Validation Accuracy: 0.2031
# Epoch [3/100], Training Loss: 2.0133, Validation Loss: 1.9550, Validation Accuracy: 0.2188
# Epoch [4/100], Training Loss: 1.9702, Validation Loss: 1.9378, Validation Accuracy: 0.2083
# Epoch [5/100], Training Loss: 1.9764, Validation Loss: 1.9234, Validation Accuracy: 0.2396
# Epoch [6/100], Training Loss: 1.9439, Validation Loss: 1.9565, Validation Accuracy: 0.2969
# Epoch [7/100], Training Loss: 1.9223, Validation Loss: 1.8980, Validation Accuracy: 0.2708
# Epoch [8/100], Training Loss: 1.8903, Validation Loss: 1.8941, Validation Accuracy: 0.2865
# Epoch [9/100], Training Loss: 1.9005, Validation Loss: 1.8990, Validation Accuracy: 0.3229
# Epoch [10/100], Training Loss: 1.8331, Validation Loss: 1.8846, Validation Accuracy: 0.2708
# Epoch [11/100], Training Loss: 1.8650, Validation Loss: 1.8527, Validation Accuracy: 0.2917
# Epoch [12/100], Training Loss: 1.8641, Validation Loss: 1.8731, Validation Accuracy: 0.2969
# Epoch [13/100], Training Loss: 1.9019, Validation Loss: 1.9207, Validation Accuracy: 0.3021
# Epoch [14/100], Training Loss: 1.8094, Validation Loss: 1.8329, Validation Accuracy: 0.2760
# Epoch [15/100], Training Loss: 1.8181, Validation Loss: 1.8802, Validation Accuracy: 0.3646
# Epoch [16/100], Training Loss: 1.8403, Validation Loss: 1.8363, Validation Accuracy: 0.3177
# Epoch [17/100], Training Loss: 1.8033, Validation Loss: 1.7790, Validation Accuracy: 0.3542
# Epoch [18/100], Training Loss: 1.8076, Validation Loss: 1.8074, Validation Accuracy: 0.3177
# Epoch [19/100], Training Loss: 1.7964, Validation Loss: 1.7860, Validation Accuracy: 0.2865
# Epoch [20/100], Training Loss: 1.7982, Validation Loss: 1.8245, Validation Accuracy: 0.3333
# Epoch [21/100], Training Loss: 1.7967, Validation Loss: 1.8606, Validation Accuracy: 0.3073
# Epoch [22/100], Training Loss: 1.7534, Validation Loss: 1.7847, Validation Accuracy: 0.3073
# Epoch [23/100], Training Loss: 1.7805, Validation Loss: 1.8130, Validation Accuracy: 0.2865
# Epoch [24/100], Training Loss: 1.7860, Validation Loss: 1.8844, Validation Accuracy: 0.3490
# Epoch [25/100], Training Loss: 1.7441, Validation Loss: 1.7899, Validation Accuracy: 0.3385
# Epoch [26/100], Training Loss: 1.7293, Validation Loss: 1.7972, Validation Accuracy: 0.3073
# Epoch [27/100], Training Loss: 1.7331, Validation Loss: 1.8474, Validation Accuracy: 0.3125
# Epoch [28/100], Training Loss: 1.7646, Validation Loss: 1.8280, Validation Accuracy: 0.2656
# Epoch [29/100], Training Loss: 1.7502, Validation Loss: 1.8158, Validation Accuracy: 0.3229
# Epoch [30/100], Training Loss: 1.7568, Validation Loss: 1.8399, Validation Accuracy: 0.3229
# Epoch [31/100], Training Loss: 1.7450, Validation Loss: 1.7598, Validation Accuracy: 0.3229
# Epoch [32/100], Training Loss: 1.7221, Validation Loss: 1.8179, Validation Accuracy: 0.2865
# Epoch [33/100], Training Loss: 1.6761, Validation Loss: 1.8351, Validation Accuracy: 0.3021
# Epoch [34/100], Training Loss: 1.7230, Validation Loss: 1.7675, Validation Accuracy: 0.2969
# Epoch [35/100], Training Loss: 1.6869, Validation Loss: 1.8239, Validation Accuracy: 0.3125
# Epoch [36/100], Training Loss: 1.6322, Validation Loss: 1.8816, Validation Accuracy: 0.3073
# Epoch [37/100], Training Loss: 1.6768, Validation Loss: 1.8587, Validation Accuracy: 0.3490
# Epoch [38/100], Training Loss: 1.6244, Validation Loss: 1.7638, Validation Accuracy: 0.3125
# Epoch [39/100], Training Loss: 1.6518, Validation Loss: 1.7670, Validation Accuracy: 0.3385
# Epoch [40/100], Training Loss: 1.6690, Validation Loss: 1.7935, Validation Accuracy: 0.3229
# Epoch [41/100], Training Loss: 1.6041, Validation Loss: 1.8506, Validation Accuracy: 0.3125
# Epoch [42/100], Training Loss: 1.5749, Validation Loss: 1.8772, Validation Accuracy: 0.2812
# Epoch [43/100], Training Loss: 1.6446, Validation Loss: 2.0086, Validation Accuracy: 0.2969
# Epoch [44/100], Training Loss: 1.6160, Validation Loss: 1.8315, Validation Accuracy: 0.2917
# Epoch [45/100], Training Loss: 1.5632, Validation Loss: 1.9115, Validation Accuracy: 0.3177
# Epoch [46/100], Training Loss: 1.4811, Validation Loss: 1.9432, Validation Accuracy: 0.3125
# Epoch [47/100], Training Loss: 1.5606, Validation Loss: 1.7270, Validation Accuracy: 0.3281
# Epoch [48/100], Training Loss: 1.5417, Validation Loss: 1.9034, Validation Accuracy: 0.3229
# Epoch [49/100], Training Loss: 1.5242, Validation Loss: 1.8969, Validation Accuracy: 0.3281
# Epoch [50/100], Training Loss: 1.5203, Validation Loss: 1.8036, Validation Accuracy: 0.3438
# Epoch [51/100], Training Loss: 1.4715, Validation Loss: 1.9959, Validation Accuracy: 0.2969
# Epoch [52/100], Training Loss: 1.4558, Validation Loss: 1.9595, Validation Accuracy: 0.3073
# Epoch [53/100], Training Loss: 1.4377, Validation Loss: 2.1729, Validation Accuracy: 0.2969
# Epoch [54/100], Training Loss: 1.4928, Validation Loss: 1.8759, Validation Accuracy: 0.3125
# Epoch [55/100], Training Loss: 1.4535, Validation Loss: 1.9638, Validation Accuracy: 0.3281
# Epoch [56/100], Training Loss: 1.4569, Validation Loss: 1.9372, Validation Accuracy: 0.2969
# Epoch [57/100], Training Loss: 1.4608, Validation Loss: 1.8180, Validation Accuracy: 0.2865
# Epoch [58/100], Training Loss: 1.3755, Validation Loss: 1.8750, Validation Accuracy: 0.3333
# Epoch [59/100], Training Loss: 1.4083, Validation Loss: 1.9239, Validation Accuracy: 0.3333
# Epoch [60/100], Training Loss: 1.3824, Validation Loss: 2.2085, Validation Accuracy: 0.2865
# Epoch [61/100], Training Loss: 1.4132, Validation Loss: 1.8603, Validation Accuracy: 0.3542
# Epoch [62/100], Training Loss: 1.4214, Validation Loss: 1.9432, Validation Accuracy: 0.2812
# Epoch [63/100], Training Loss: 1.2965, Validation Loss: 2.0230, Validation Accuracy: 0.2552
# Epoch [64/100], Training Loss: 1.3622, Validation Loss: 1.7355, Validation Accuracy: 0.3542
# Epoch [65/100], Training Loss: 1.2680, Validation Loss: 2.3121, Validation Accuracy: 0.2708
# Epoch [66/100], Training Loss: 1.4037, Validation Loss: 1.9735, Validation Accuracy: 0.3125
# Epoch [67/100], Training Loss: 1.3813, Validation Loss: 1.8974, Validation Accuracy: 0.3281
# Epoch [68/100], Training Loss: 1.3321, Validation Loss: 1.9589, Validation Accuracy: 0.3750
# Epoch [69/100], Training Loss: 1.2543, Validation Loss: 1.8870, Validation Accuracy: 0.3177
# Epoch [70/100], Training Loss: 1.2399, Validation Loss: 2.1908, Validation Accuracy: 0.3385
# Epoch [71/100], Training Loss: 1.2153, Validation Loss: 2.0476, Validation Accuracy: 0.2760
# Epoch [72/100], Training Loss: 1.1915, Validation Loss: 2.0027, Validation Accuracy: 0.3177
# Epoch [73/100], Training Loss: 1.2496, Validation Loss: 2.6525, Validation Accuracy: 0.3490
# Epoch [74/100], Training Loss: 1.3462, Validation Loss: 1.9045, Validation Accuracy: 0.3385
# Epoch [75/100], Training Loss: 1.2216, Validation Loss: 2.2374, Validation Accuracy: 0.3542
# Epoch [76/100], Training Loss: 1.1909, Validation Loss: 1.9827, Validation Accuracy: 0.3698
# Epoch [77/100], Training Loss: 1.1333, Validation Loss: 2.0972, Validation Accuracy: 0.3750
# Epoch [78/100], Training Loss: 1.0547, Validation Loss: 2.1526, Validation Accuracy: 0.3333
# Epoch [79/100], Training Loss: 1.1340, Validation Loss: 2.1242, Validation Accuracy: 0.2865
# Epoch [80/100], Training Loss: 1.1124, Validation Loss: 2.1117, Validation Accuracy: 0.3281
# Epoch [81/100], Training Loss: 1.1405, Validation Loss: 1.9550, Validation Accuracy: 0.3542
# Epoch [82/100], Training Loss: 1.1238, Validation Loss: 2.2284, Validation Accuracy: 0.3438
# Epoch [83/100], Training Loss: 1.0510, Validation Loss: 2.2248, Validation Accuracy: 0.3646
# Epoch [84/100], Training Loss: 1.1484, Validation Loss: 2.0628, Validation Accuracy: 0.3698
# Epoch [85/100], Training Loss: 0.9793, Validation Loss: 2.3241, Validation Accuracy: 0.3490
# Epoch [86/100], Training Loss: 1.0237, Validation Loss: 2.2553, Validation Accuracy: 0.3594
# Epoch [87/100], Training Loss: 1.0545, Validation Loss: 2.3839, Validation Accuracy: 0.3281
# Epoch [88/100], Training Loss: 1.0144, Validation Loss: 2.3825, Validation Accuracy: 0.3594
# Epoch [89/100], Training Loss: 1.0177, Validation Loss: 2.1230, Validation Accuracy: 0.3333
# Epoch [90/100], Training Loss: 0.9623, Validation Loss: 2.7860, Validation Accuracy: 0.3073
# Epoch [91/100], Training Loss: 0.9620, Validation Loss: 2.2845, Validation Accuracy: 0.2500
# Epoch [92/100], Training Loss: 0.9245, Validation Loss: 2.4518, Validation Accuracy: 0.4062
# Epoch [93/100], Training Loss: 0.9804, Validation Loss: 2.4711, Validation Accuracy: 0.3333
# Epoch [94/100], Training Loss: 0.9171, Validation Loss: 2.5748, Validation Accuracy: 0.3542
# Epoch [95/100], Training Loss: 0.9980, Validation Loss: 2.1988, Validation Accuracy: 0.3646
# Epoch [96/100], Training Loss: 0.9740, Validation Loss: 2.2552, Validation Accuracy: 0.3229
# Epoch [97/100], Training Loss: 0.9113, Validation Loss: 2.7488, Validation Accuracy: 0.3281
# Epoch [98/100], Training Loss: 0.9854, Validation Loss: 2.3996, Validation Accuracy: 0.3594
# Epoch [99/100], Training Loss: 0.8616, Validation Loss: 2.4261, Validation Accuracy: 0.3438

# %%
def plot_accuracies(history):
    accuracies = [x['validation_accuracy'] for x in history]
    plt.plot(accuracies, '-x')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Accuracy vs Number of epochs')

plot_accuracies(history)

# %%
def plot_losses(history):
    train_losses = [x.get('train_loss') for x in history]
    val_losses = [x['validation_loss'] for x in history]
    plt.plot(train_losses, '-bx')
    plt.plot(val_losses, '-rx')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(['Training', 'Validation'])
    plt.title('Loss vs Number of epochs')

plot_losses(history)

# %% [markdown]
# The model also seems to be overfitting as the training loss is getting lower but the validation loss is getting higher, and the dropout value helped a little bit but not much for solving the overfitting issue.
#
# If we take the point `Epoch [30/100], Training Loss: 1.7568, Validation Loss: 1.8399, Validation Accuracy: 0.3229` as the point where validation loss goes higher while training loss drops by looking at Loss vs Number of Epochs plot, then our accuracy can be considered as `35%`

# %%
evaluate(model, test_dataloader)
# Out:
# {'validation_loss': 2.6164968013763428,
#  'validation_accuracy': 0.3310810923576355}

# %% [markdown]
# **Test Accuracy**: 33%

# %%
torch.save(model.state_dict(), 'dropout7_1.pth')
